# %% [markdown]
# <a href="https://colab.research.google.com/github/leviathan519/Swapsy/blob/main/Data_Extraction_using_patool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install patool
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.7/93.7 kB 2.4 MB/s eta 0:00:00
# ...

# %%
import patoolib
patoolib.extract_archive("/content/DATA1.zip",outdir='/content/')
# Out:
# INFO patool: Extracting /content/DATA1.zip ...
# INFO:patool:Extracting /content/DATA1.zip ...
# INFO patool: running /usr/bin/7z x -o/content/ -- /content/DATA1.zip
# INFO:patool:running /usr/bin/7z x -o/content/ -- /content/DATA1.zip
# INFO patool:     with input=''
# INFO:patool:    with input=''
# ---------------------------------------------------------------------------
# PatoolError                               Traceback (most recent call last)
# <ipython-input-2-fefd43a279a2> in <cell line: 2>()
#       1 import patoolib
# ----> 2 patoolib.extract_archive("/content/DATA1.zip",outdir='/content/')
#
# /usr/local/lib/python3.10/dist-packages/patoolib/__init__.py in extract_archive(archive, verbosity, outdir, program, interactive, password)
#     737     if verbosity >= 0:
#     738         log.log_info(f"Extracting {archive} ...")
# --> 739     return _extract_archive(archive, verbosity=verbosity, interactive=interactive, outdir=outdir, program=program, password=password)
# ...

# %%
import pandas as pd
df=pd.read_csv("OP_DTL_GNRL_PGYR2022_P06302023.csv",error_bad_lines=False, engine="python")
# Out:
# <ipython-input-3-4082c9762819>:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df=pd.read_csv("OP_DTL_GNRL_PGYR2022_P06302023.csv",error_bad_lines=False, engine="python")

# %%
df.head()
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN  \
# 0         NEW  Covered Recipient Physician                    NaN
# 1         NEW  Covered Recipient Physician                    NaN
# 2         NEW  Covered Recipient Physician                    NaN
# 3         NEW  Covered Recipient Physician                    NaN
# 4         NEW  Covered Recipient Physician                    NaN
#
#    Teaching_Hospital_ID Teaching_Hospital_Name  Covered_Recipient_Profile_ID  \
# 0                   NaN                    NaN                      331678.0
# 1                   NaN                    NaN                      376079.0
# 2                   NaN                    NaN                      590939.0
# 3                   NaN                    NaN                      940116.0
# 4                   NaN                    NaN                      164202.0
#
#    Covered_Recipient_NPI Covered_Recipient_First_Name  \
# ...

# %%
df['Teaching_Hospital_ID'].value_counts()
# Out:
# 11436.0    533
# 12153.0    119
# 11916.0     92
# 12660.0     85
# 12118.0     79
#           ...
# 11446.0      1
# 12238.0      1
# 11589.0      1
# 12546.0      1
# 12114.0      1
# Name: Teaching_Hospital_ID, Length: 533, dtype: int64

# %%
df.columns
# Out:
# Index(['Change_Type', 'Covered_Recipient_Type', 'Teaching_Hospital_CCN',
#        'Teaching_Hospital_ID', 'Teaching_Hospital_Name',
#        'Covered_Recipient_Profile_ID', 'Covered_Recipient_NPI',
#        'Covered_Recipient_First_Name', 'Covered_Recipient_Middle_Name',
#        'Covered_Recipient_Last_Name', 'Covered_Recipient_Name_Suffix',
#        'Recipient_Primary_Business_Street_Address_Line1',
#        'Recipient_Primary_Business_Street_Address_Line2', 'Recipient_City',
#        'Recipient_State', 'Recipient_Zip_Code', 'Recipient_Country',
#        'Recipient_Province', 'Recipient_Postal_Code',
#        'Covered_Recipient_Primary_Type_1', 'Covered_Recipient_Primary_Type_2',
#        'Covered_Recipient_Primary_Type_3', 'Covered_Recipient_Primary_Type_4',
#        'Covered_Recipient_Primary_Type_5', 'Covered_Recipient_Primary_Type_6',
#        'Covered_Recipient_Specialty_1', 'Covered_Recipient_Specialty_2',
# ...

# %%
df.columns
# Out:
# Index(['Change_Type', 'Covered_Recipient_Type', 'Teaching_Hospital_CCN',
#        'Teaching_Hospital_ID', 'Teaching_Hospital_Name',
#        'Covered_Recipient_Profile_ID', 'Covered_Recipient_NPI',
#        'Covered_Recipient_First_Name', 'Covered_Recipient_Middle_Name',
#        'Covered_Recipient_Last_Name', 'Covered_Recipient_Name_Suffix',
#        'Recipient_Primary_Business_Street_Address_Line1',
#        'Recipient_Primary_Business_Street_Address_Line2', 'Recipient_City',
#        'Recipient_State', 'Recipient_Zip_Code', 'Recipient_Country',
#        'Recipient_Province', 'Recipient_Postal_Code',
#        'Covered_Recipient_Primary_Type_1', 'Covered_Recipient_Primary_Type_2',
#        'Covered_Recipient_Primary_Type_3', 'Covered_Recipient_Primary_Type_4',
#        'Covered_Recipient_Primary_Type_5', 'Covered_Recipient_Primary_Type_6',
#        'Covered_Recipient_Specialty_1', 'Covered_Recipient_Specialty_2',
# ...
