# %%
import tensorflow as tf 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# Preprocessing the Datasets

# %%
train_datagen = ImageDataGenerator(rescale = 1./255, shear_range = 0.2, zoom_range=0.2,horizontal_flip= True)

# %%
traininng_set = train_datagen.flow_from_directory(r'C:\Users\swapn\Documents\Python\udemy deep learning\Section 40 - Convolutional Neural Networks (CNN)\dataset\training_set',target_size=(64,64),batch_size = 32,class_mode='binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %%
#Now we will pre process the test set. but only resize it. nothing more because we don't want to morph the image
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
test_set = test_datagen.flow_from_directory(r'C:\Users\swapn\Documents\Python\udemy deep learning\Section 40 - Convolutional Neural Networks (CNN)\dataset\test_set',target_size=(64,64),batch_size = 32,class_mode='binary')
# Out:
# Found 4000 images belonging to 3 classes.

# %% [markdown]
# Building the CNN

# %%
cnn = tf.keras.models.Sequential()

# %%
#!st Convolutional Layer
cnn.add(tf.keras.layers.Conv2D(filters = 32,kernel_size=3,activation = 'relu',input_shape =(64,64,3)))
# Out:
# c:\Users\swapn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#dropout layer
from keras.layers import Dropout
cnn.add(Dropout(0.2))

# %%
#1st pooling layer
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides = 2,padding = "same"))

# %%
#2nd Covolutional Leyr
cnn.add(tf.keras.layers.Conv2D(filters = 32,kernel_size=3,activation = 'relu'))

# %%
#dropout layer
from keras.layers import Dropout
cnn.add(Dropout(0.2))

# %%
#2nd Pooling layer
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides = 2,padding = "same"))

# %%
#Flattening Layer
cnn.add(tf.keras.layers.Flatten())

# %%
#Full Connection
cnn.add(tf.keras.layers.Dense(units = 128, activation = 'relu'))

# %%
#Output layer
cnn.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# %%
#compiling
cnn.compile(optimizer = 'adam',loss = 'binary_crossentropy',metrics = ['accuracy'])

# %%
#training the cnn on training set and evaluating on test set
cnn.fit(x = traininng_set,validation_data = test_set,epochs = 25)
# Out:
# Epoch 1/25
# c:\Users\swapn\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 90s 334ms/step - accuracy: 0.5543 - loss: 0.6849 - val_accuracy: 0.3153 - val_loss: 0.6229
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 77s 305ms/step - accuracy: 0.6820 - loss: 0.5959 - val_accuracy: 0.3165 - val_loss: 0.6428
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 86s 338ms/step - accuracy: 0.7052 - loss: 0.5709 - val_accuracy: 0.2812 - val_loss: 0.5777
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 76s 298ms/step - accuracy: 0.7321 - loss: 0.5400 - val_accuracy: 0.3245 - val_loss: 0.7283
# Epoch 5/25
# ...

# %%
#making a sinngle predicton
import numpy as np
from keras.preprocessing import image

# %%
#loading a image
test_img = image.load_img(r'C:\Users\swapn\Documents\Python\udemy deep learning\Section 40 - Convolutional Neural Networks (CNN)\dataset\test_set\dogs\dog.4014.jpg',
                          target_size=(64,64))
#resizing the test image as we had resized all images.

# %%
#now since cnn expects image to be in array format, converting image to array
test_img=image.img_to_array(test_img)
#since, our model was trained in batches of image, our input format also should be in batches.
test_img = np.expand_dims(test_img,axis=0)

# %% [markdown]
# now before classification, i would like to know which values(0 or 1) correspond to which class.

# %%
traininng_set.class_indices
# Out:
# {'cats': 0, 'dogs': 1}

# %%
#prediction
result = cnn.predict(test_img/255.0)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step

# %%
#Obtaining output
predicted =''
if result[0][0] >= 0.5:
   predicted= 'Dog'
elif result[0][0]  <= 0.5:
   predicted= 'Cat'

# %%
print(predicted)
# Out:
# Dog

# %%
import matplotlib.pyplot as plt

# %%
Prediction = [ ]
import os
import re
from PIL import Image
input_dir = r'C:\Users\swapn\Documents\Python\udemy deep learning\Section 40 - Convolutional Neural Networks (CNN)\dataset\test_set\Combined'
image_names = os.listdir(input_dir)
for img in image_names:
    img1 = image.load_img(os.path.join(input_dir,img),target_size=(64,64))
    img2 = np.expand_dims(image.img_to_array(img1),axis=0)
    result1 = cnn.predict(img2/255.0)
    if result1[0][0] >=0.5 :
       Prediction.append  ('Woof!')
    else:
       Prediction.append('Meow!')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# ...

# %%
Grnd_truth = [ ]
#input_dir = r'C:\Users\swapn\Documents\Python\udemy deep learning\Section 40 - Convolutional Neural Networks (CNN)\dataset\test_set\Combined'
image_names = np.array(os.listdir(input_dir))
for i in range(2000):
    if 'cat' in image_names[i]:
       Grnd_truth.append('Meow!')
    else: 
       Grnd_truth.append('Woof!')

# %%
from sklearn import confusion_matrix 
confusion_matrix = metrics.confusion_matrix(np.array(Grnd_truth),np.array(Prediction))

# %%
print(confusion_matrix)
# Out:
# [[838 162]
#  [215 785]]
